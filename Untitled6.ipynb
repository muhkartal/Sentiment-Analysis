# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2317738999378250262
#  xla_global_id: -1]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# !unzip "/content/drive/MyDrive/Content/VisDrone2020-CC.zip"
# Out:
# Archive:  /content/drive/MyDrive/Content/VisDrone2020-CC.zip
#    creating: VisDrone2020-CC/
#    creating: VisDrone2020-CC/annotations/
#   inflating: VisDrone2020-CC/annotations/00001.txt
#   inflating: VisDrone2020-CC/annotations/00002.txt
#   inflating: VisDrone2020-CC/annotations/00003.txt
#   inflating: VisDrone2020-CC/annotations/00004.txt
#   inflating: VisDrone2020-CC/annotations/00005.txt
#   inflating: VisDrone2020-CC/annotations/00006.txt
#   inflating: VisDrone2020-CC/annotations/00007.txt
#   inflating: VisDrone2020-CC/annotations/00008.txt
#   inflating: VisDrone2020-CC/annotations/00009.txt
#   inflating: VisDrone2020-CC/annotations/00010.txt
#   inflating: VisDrone2020-CC/annotations/00012.txt
#   inflating: VisDrone2020-CC/annotations/00013.txt
#   inflating: VisDrone2020-CC/annotations/00014.txt
#   inflating: VisDrone2020-CC/annotations/00019.txt
#   inflating: VisDrone2020-CC/annotations/00020.txt
#   inflating: VisDrone2020-CC/annotations/00021.txt
#   inflating: VisDrone2020-CC/annotations/00025.txt
#   inflating: VisDrone2020-CC/annotations/00026.txt
#   inflating: VisDrone2020-CC/annotations/00027.txt
#   inflating: VisDrone2020-CC/annotations/00028.txt
#   inflating: VisDrone2020-CC/annotations/00029.txt
#   inflating: VisDrone2020-CC/annotations/00030.txt
#   inflating: VisDrone2020-CC/annotations/00031.txt
#   inflating: VisDrone2020-CC/annotations/00032.txt
#   inflating: VisDrone2020-CC/annotations/00033.txt
#   inflating: VisDrone2020-CC/annotations/00036.txt
#   inflating: VisDrone2020-CC/annotations/00037.txt
#   inflating: VisDrone2020-CC/annotations/00038.txt
#   inflating: VisDrone2020-CC/annotations/00039.txt
#   inflating: VisDrone2020-CC/annotations/00040.txt
#   inflating: VisDrone2020-CC/annotations/00041.txt
#   inflating: VisDrone2020-CC/annotations/00045.txt
#   inflating: VisDrone2020-CC/annotations/00046.txt
#   inflating: VisDrone2020-CC/annotations/00047.txt
#   inflating: VisDrone2020-CC/annotations/00048.txt
#   inflating: VisDrone2020-CC/annotations/00049.txt
#   inflating: VisDrone2020-CC/annotations/00050.txt
#   inflating: VisDrone2020-CC/annotations/00051.txt
#   inflating: VisDrone2020-CC/annotations/00052.txt
#   inflating: VisDrone2020-CC/annotations/00053.txt
#   inflating: VisDrone2020-CC/annotations/00054.txt
#   inflating: VisDrone2020-CC/annotations/00055.txt
#   inflating: VisDrone2020-CC/annotations/00056.txt
#   inflating: VisDrone2020-CC/annotations/00057.txt
#   inflating: VisDrone2020-CC/annotations/00058.txt
#   inflating: VisDrone2020-CC/annotations/00059.txt
#   inflating: VisDrone2020-CC/annotations/00060.txt
#   inflating: VisDrone2020-CC/annotations/00064.txt
#   inflating: VisDrone2020-CC/annotations/00066.txt
#   inflating: VisDrone2020-CC/annotations/00067.txt
#   inflating: VisDrone2020-CC/annotations/00068.txt
#   inflating: VisDrone2020-CC/annotations/00071.txt
#   inflating: VisDrone2020-CC/annotations/00072.txt
#   inflating: VisDrone2020-CC/annotations/00073.txt
#   inflating: VisDrone2020-CC/annotations/00076.txt
#   inflating: VisDrone2020-CC/annotations/00077.txt
#   inflating: VisDrone2020-CC/annotations/00078.txt
#   inflating: VisDrone2020-CC/annotations/00079.txt
#   inflating: VisDrone2020-CC/annotations/00080.txt
#   inflating: VisDrone2020-CC/annotations/00081.txt
#   inflating: VisDrone2020-CC/annotations/00083.txt
#   inflating: VisDrone2020-CC/annotations/00084.txt
#   inflating: VisDrone2020-CC/annotations/00085.txt
#   inflating: VisDrone2020-CC/annotations/00086.txt
#   inflating: VisDrone2020-CC/annotations/00087.txt
#   inflating: VisDrone2020-CC/annotations/00089.txt
#   inflating: VisDrone2020-CC/annotations/00090.txt
#   inflating: VisDrone2020-CC/annotations/00091.txt
#   inflating: VisDrone2020-CC/annotations/00092.txt
#   inflating: VisDrone2020-CC/annotations/00093.txt
#   inflating: VisDrone2020-CC/annotations/00094.txt
#   inflating: VisDrone2020-CC/annotations/00096.txt
#   inflating: VisDrone2020-CC/annotations/00097.txt
#   inflating: VisDrone2020-CC/annotations/00098.txt
#   inflating: VisDrone2020-CC/annotations/00099.txt
#   inflating: VisDrone2020-CC/annotations/00100.txt
#   inflating: VisDrone2020-CC/annotations/00102.txt
#   inflating: VisDrone2020-CC/annotations/00104.txt
#   inflating: VisDrone2020-CC/annotations/00106.txt
#   inflating: VisDrone2020-CC/annotations/00107.txt
#   inflating: VisDrone2020-CC/annotations/00109.txt
#   inflating: VisDrone2020-CC/annotations/00110.txt
#    creating: VisDrone2020-CC/sequences/
#    creating: VisDrone2020-CC/sequences/00001/
#   inflating: VisDrone2020-CC/sequences/00001/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00001/00030.jpg
#    creating: VisDrone2020-CC/sequences/00002/
#   inflating: VisDrone2020-CC/sequences/00002/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00002/00030.jpg
#    creating: VisDrone2020-CC/sequences/00003/
#   inflating: VisDrone2020-CC/sequences/00003/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00003/00030.jpg
#    creating: VisDrone2020-CC/sequences/00004/
#   inflating: VisDrone2020-CC/sequences/00004/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00004/00030.jpg
#    creating: VisDrone2020-CC/sequences/00005/
#   inflating: VisDrone2020-CC/sequences/00005/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00005/00030.jpg
#    creating: VisDrone2020-CC/sequences/00006/
#   inflating: VisDrone2020-CC/sequences/00006/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00006/00030.jpg
#    creating: VisDrone2020-CC/sequences/00007/
#   inflating: VisDrone2020-CC/sequences/00007/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00007/00030.jpg
#    creating: VisDrone2020-CC/sequences/00008/
#   inflating: VisDrone2020-CC/sequences/00008/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00008/00030.jpg
#    creating: VisDrone2020-CC/sequences/00009/
#   inflating: VisDrone2020-CC/sequences/00009/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00009/00030.jpg
#    creating: VisDrone2020-CC/sequences/00010/
#   inflating: VisDrone2020-CC/sequences/00010/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00010/00030.jpg
#    creating: VisDrone2020-CC/sequences/00011/
#   inflating: VisDrone2020-CC/sequences/00011/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00011/00030.jpg
#    creating: VisDrone2020-CC/sequences/00012/
#   inflating: VisDrone2020-CC/sequences/00012/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00012/00030.jpg
#    creating: VisDrone2020-CC/sequences/00013/
#   inflating: VisDrone2020-CC/sequences/00013/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00013/00030.jpg
#    creating: VisDrone2020-CC/sequences/00014/
#   inflating: VisDrone2020-CC/sequences/00014/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00014/00030.jpg
#    creating: VisDrone2020-CC/sequences/00015/
#   inflating: VisDrone2020-CC/sequences/00015/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00015/00030.jpg
#    creating: VisDrone2020-CC/sequences/00016/
#   inflating: VisDrone2020-CC/sequences/00016/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00016/00030.jpg
#    creating: VisDrone2020-CC/sequences/00017/
#   inflating: VisDrone2020-CC/sequences/00017/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00017/00030.jpg
#    creating: VisDrone2020-CC/sequences/00018/
#   inflating: VisDrone2020-CC/sequences/00018/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00018/00030.jpg
#    creating: VisDrone2020-CC/sequences/00019/
#   inflating: VisDrone2020-CC/sequences/00019/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00019/00030.jpg
#    creating: VisDrone2020-CC/sequences/00020/
#   inflating: VisDrone2020-CC/sequences/00020/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00020/00030.jpg
#    creating: VisDrone2020-CC/sequences/00021/
#   inflating: VisDrone2020-CC/sequences/00021/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00021/00030.jpg
#    creating: VisDrone2020-CC/sequences/00022/
#   inflating: VisDrone2020-CC/sequences/00022/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00022/00030.jpg
#    creating: VisDrone2020-CC/sequences/00023/
#   inflating: VisDrone2020-CC/sequences/00023/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00023/00030.jpg
#    creating: VisDrone2020-CC/sequences/00024/
#   inflating: VisDrone2020-CC/sequences/00024/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00024/00030.jpg
#    creating: VisDrone2020-CC/sequences/00025/
#   inflating: VisDrone2020-CC/sequences/00025/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00025/00022.jpg
# ...
#   inflating: VisDrone2020-CC/sequences/00103/00030.jpg
#    creating: VisDrone2020-CC/sequences/00104/
#   inflating: VisDrone2020-CC/sequences/00104/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00104/00030.jpg
#    creating: VisDrone2020-CC/sequences/00105/
#   inflating: VisDrone2020-CC/sequences/00105/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00105/00030.jpg
#    creating: VisDrone2020-CC/sequences/00106/
#   inflating: VisDrone2020-CC/sequences/00106/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00106/00030.jpg
#    creating: VisDrone2020-CC/sequences/00107/
#   inflating: VisDrone2020-CC/sequences/00107/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00107/00030.jpg
#    creating: VisDrone2020-CC/sequences/00108/
#   inflating: VisDrone2020-CC/sequences/00108/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00108/00030.jpg
#    creating: VisDrone2020-CC/sequences/00109/
#   inflating: VisDrone2020-CC/sequences/00109/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00109/00030.jpg
#    creating: VisDrone2020-CC/sequences/00110/
#   inflating: VisDrone2020-CC/sequences/00110/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00110/00030.jpg
#    creating: VisDrone2020-CC/sequences/00111/
#   inflating: VisDrone2020-CC/sequences/00111/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00111/00030.jpg
#    creating: VisDrone2020-CC/sequences/00112/
#   inflating: VisDrone2020-CC/sequences/00112/00001.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00002.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00003.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00004.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00005.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00006.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00007.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00008.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00009.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00010.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00011.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00012.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00013.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00014.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00015.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00016.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00017.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00018.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00019.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00020.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00021.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00022.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00023.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00024.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00025.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00026.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00027.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00028.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00029.jpg
#   inflating: VisDrone2020-CC/sequences/00112/00030.jpg
#   inflating: VisDrone2020-CC/testlist.txt
#   inflating: VisDrone2020-CC/trainlist.txt

# %%
#Install modules
# !pip install tensorflow
# !pip install scikit-learn
# !pip install opencv-python
# !pip install tqdm
# !pip install Pillow
# !pip install h5py
# !pip install matplotlib
#Import all modules from tensorflow.keras to maintain consistency.
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.metrics import mean_squared_error
from tensorflow.keras.initializers import RandomNormal
# from tensorflow.keras.applications.vgg19 import VGG19 #commented out since it was not imported
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import model_from_json
from matplotlib import cm as CM
import matplotlib.pyplot as plt
import tensorflow as tf
from tqdm import tqdm
import scipy.io as io
from PIL import Image
import PIL
import h5py
import os
import glob
import cv2
import numpy as np
import random
import math
import sys
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
root = '/content/'

# %%
dataset_dir = os.path.join(root, 'sequences')  # Assuming all folders are in 'sequences'

# %%
import os
import glob

dataset_dir = "/content/drive/MyDrive/Content/VisDrone2020-CC/sequences"  # Replace with your dataset directory path

# Dictionary to store image paths for each subfolder
img_paths_dict = {}

for folder_path in glob.glob(os.path.join(dataset_dir, '*')):  # Get all subdirectories in 'sequences'
    if os.path.isdir(folder_path):  # Ensure it's a folder
        folder_name = os.path.basename(folder_path)  # Extract the subfolder name (e.g., '00001')
        img_paths_dict[folder_name] = []  # Initialize a list for this subfolder
        for img_path in glob.glob(os.path.join(folder_path, '*.jpg')):  # Get all .jpg files in the subfolder
            img_paths_dict[folder_name].append(img_path)

# Print the results
for folder, img_list in img_paths_dict.items():
    print(f"Folder {folder} contains {len(img_list)} images.")
print("Total subfolders:", len(img_paths_dict))
# Out:
# Folder 00098 contains 30 images.
# Folder 00099 contains 30 images.
# Folder 00100 contains 30 images.
# Folder 00101 contains 30 images.
# Folder 00102 contains 30 images.
# Folder 00104 contains 30 images.
# Folder 00103 contains 30 images.
# Folder 00106 contains 30 images.
# Folder 00105 contains 30 images.
# Folder 00107 contains 30 images.
# Folder 00109 contains 30 images.
# Folder 00108 contains 30 images.
# Folder 00110 contains 30 images.
# Folder 00111 contains 30 images.
# Folder 00112 contains 30 images.
# Folder 00001 contains 30 images.
# Folder 00002 contains 30 images.
# Folder 00003 contains 30 images.
# Folder 00004 contains 30 images.
# Folder 00005 contains 30 images.
# Folder 00006 contains 30 images.
# Folder 00007 contains 30 images.
# Folder 00008 contains 30 images.
# Folder 00009 contains 30 images.
# Folder 00010 contains 30 images.
# Folder 00011 contains 30 images.
# Folder 00012 contains 30 images.
# Folder 00013 contains 30 images.
# Folder 00014 contains 30 images.
# Folder 00015 contains 30 images.
# Folder 00016 contains 30 images.
# Folder 00017 contains 30 images.
# Folder 00018 contains 30 images.
# Folder 00019 contains 30 images.
# Folder 00020 contains 30 images.
# Folder 00021 contains 30 images.
# Folder 00022 contains 30 images.
# Folder 00023 contains 30 images.
# Folder 00024 contains 30 images.
# Folder 00025 contains 30 images.
# Folder 00026 contains 30 images.
# Folder 00027 contains 30 images.
# Folder 00028 contains 30 images.
# Folder 00029 contains 30 images.
# Folder 00030 contains 30 images.
# Folder 00031 contains 30 images.
# Folder 00032 contains 30 images.
# Folder 00033 contains 30 images.
# Folder 00034 contains 30 images.
# Folder 00035 contains 30 images.
# Folder 00036 contains 30 images.
# Folder 00037 contains 30 images.
# Folder 00038 contains 30 images.
# Folder 00039 contains 30 images.
# Folder 00040 contains 30 images.
# Folder 00041 contains 30 images.
# Folder 00042 contains 30 images.
# Folder 00043 contains 30 images.
# Folder 00044 contains 30 images.
# Folder 00045 contains 30 images.
# Folder 00046 contains 30 images.
# Folder 00047 contains 30 images.
# Folder 00048 contains 30 images.
# Folder 00049 contains 30 images.
# Folder 00050 contains 30 images.
# Folder 00051 contains 30 images.
# Folder 00052 contains 30 images.
# Folder 00053 contains 30 images.
# Folder 00054 contains 30 images.
# Folder 00055 contains 30 images.
# Folder 00056 contains 30 images.
# Folder 00057 contains 30 images.
# Folder 00058 contains 30 images.
# Folder 00059 contains 30 images.
# Folder 00060 contains 30 images.
# Folder 00061 contains 30 images.
# Folder 00062 contains 30 images.
# Folder 00063 contains 30 images.
# Folder 00064 contains 30 images.
# Folder 00065 contains 30 images.
# Folder 00066 contains 30 images.
# Folder 00067 contains 30 images.
# Folder 00068 contains 30 images.
# Folder 00069 contains 30 images.
# Folder 00070 contains 30 images.
# Folder 00071 contains 30 images.
# Folder 00072 contains 30 images.
# Folder 00073 contains 30 images.
# Folder 00074 contains 30 images.
# Folder 00075 contains 30 images.
# Folder 00076 contains 30 images.
# Folder 00077 contains 30 images.
# Folder 00078 contains 30 images.
# Folder 00079 contains 30 images.
# Folder 00080 contains 30 images.
# Folder 00081 contains 30 images.
# Folder 00082 contains 30 images.
# Folder 00083 contains 30 images.
# Folder 00084 contains 30 images.
# Folder 00085 contains 30 images.
# Folder 00086 contains 30 images.
# Folder 00087 contains 30 images.
# Folder 00088 contains 30 images.
# Folder 00089 contains 30 images.
# Folder 00090 contains 30 images.
# Folder 00091 contains 30 images.
# Folder 00092 contains 30 images.
# Folder 00093 contains 30 images.
# Folder 00094 contains 30 images.
# Folder 00095 contains 30 images.
# Folder 00096 contains 30 images.
# Folder 00097 contains 30 images.
# Total subfolders: 112

# %%
img_paths_train = []
train_sum = 0

# Loop through each subfolder and collect image paths
for subfolder, img_list in img_paths_dict.items():  # Use img_paths_dict from the previous code
    img_paths_train.extend(img_list)  # Add all images from the subfolder to the train list

# Print the results
train_sum = len(img_paths_train)
print("Train image importation .. Total images:", train_sum)
# Out:
# Train image importation .. Total images: 3360

# %%
# --- Test set paths ----------------------------------------------------------
img_paths_test = []
test_sum = 0

# Loop through each sub‑folder in the **test** dictionary and collect image paths
for subfolder, img_list in img_paths_dict.items():  # use your test‑set dict here
    img_paths_test.extend(img_list)                      # add all images from that subfolder

# Print the results
test_sum = len(img_paths_test)
print("Test image importation .. Total images:", test_sum)
# Out:
# Test image importation .. Total images: 3360

# %%
def create_img(path):
    #Function to load,normalize and return image
    im = Image.open(path).convert('RGB')
    """width, height = im.size
    newsize = (width // 2, height //2)
    im = im.resize(newsize)"""
    im = np.array(im)

    im = im/255.0

    im[:,:,0]=(im[:,:,0]-0.485)/0.229
    im[:,:,1]=(im[:,:,1]-0.456)/0.224
    im[:,:,2]=(im[:,:,2]-0.406)/0.225

    #print(im.shape)
    #im = np.expand_dims(im,axis  = 0)
    return im

def get_input(path):
    #print(path)
    path = path[0]
    img = create_img(path)
    return(img)

def get_output(path):
    #import target
    #resize target
    #print(path)
    gt_file = h5py.File(path,'r')
    target = np.asarray(gt_file['density'])
    img = cv2.resize(target,(int(target.shape[1]//8),int(target.shape[0]//8)),interpolation = cv2.INTER_CUBIC)*64
    img = np.expand_dims(img,axis  = 2)
    #print(img.shape)
    return img

def preprocess_input(image,target):
    #crop image
    #crop target
    #resize target
    crop_size = (int(image.shape[0]/2),int(image.shape[1]/2))
    #imm = np.resize(image,((image.shape[0]//2),int(image.shape[1]//2)))
    #tar = np.resize(target,((image.shape[0]//2),int(image.shape[1]//2)))
    if random.randint(0,9)<= -1:
            dx = int(random.randint(0,1)*image.shape[0]*1./2)
            dy = int(random.randint(0,1)*image.shape[1]*1./2)
    else:
            dx = int(random.random()*image.shape[0]*1./2)
            dy = int(random.random()*image.shape[1]*1./2)

    #print(crop_size , dx , dy)
    img = image[dx : crop_size[0]+dx , dy:crop_size[1]+dy]

    target_aug = target[dx:crop_size[0]+dx,dy:crop_size[1]+dy]
    #print(img.shape)

    return(img,target_aug)

# %%
#Image data generator
def image_generator(files, batch_size = 64):
    while True:
        input_path = np.random.choice(a = files, size = batch_size)
        #print(input_path)
        batch_input = []
        batch_output = []

        #for input_path in batch_paths:

        inputt = get_input(input_path)
        output = get_output(input_path[0].replace('.jpg','.h5').replace('sequences','ground_truth') )

        batch_input += [inputt]
        batch_output += [output]

        batch_x = np.append(batch_x, batch_xx)
        batch_y = np.append(batch_y, batch_yy)
        yield( batch_x, batch_y )

# %%
def save_mod(model , str1 , str2):
    model.save_weights(str1)
    model_json = model.to_json()
    with open(str2, "w") as json_file:
        json_file.write(model_json)

# %%
def init_weights_vgg(model):
    #vgg =  VGG16(weights='imagenet', include_top=False)

    json_file = open('/content/drive/MyDrive/Content/VisDrone2020-CC/VGG_16.json', 'r' )
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    # loaded_model.load_weights("/content/CSRNet-keras/weights/VGG_16.h5")

    vgg = loaded_model

    vgg_weights=[]
    for layer in vgg.layers:
        if('conv' in layer.name):
            vgg_weights.append(layer.get_weights())
    offset=0
    i=0
    while(i<10):
        if('conv' in model.layers[i+offset].name):
            model.layers[i+offset].set_weights(vgg_weights[i])
            i=i+1

        else:
            offset=offset+1

    return (model)

# %%
def euclidean_distance_loss(y_true, y_pred):
    # Euclidean distance as a measure of loss (Loss function)
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1))

# %%
def mae(y_true, y_pred):
    return abs(K.sum(y_true) - K.sum(y_pred))
    #return mean_absolute_error(np.array(K.sum(y_true)),np.array(K.sum(y_pred)))
def mse(y_true, y_pred):
    #return tf.math.sqrt((K.sum(y_true) - K.sum(y_pred)) * (K.sum(y_true) - K.sum(y_pred)))
    #tf.keras.losses.mean_squared_error(y_true, y_pred)
    return tf.math.sqrt(K.sum(y_true) * K.sum(y_pred))
    #return tf.math.sqrt(K.sum(y_true) - K.sum(y_pred))

# %%
def CrowdNet():
            #Variable Input Size
            rows = None
            cols = None

            #Batch Normalisation option

            batch_norm = 0
            kernel = (3, 3)
            init = RandomNormal(stddev=0.01)
            model = Sequential()
            #custom VGG:

            if(batch_norm):
                model.add(Conv2D(64, kernel_size = kernel,  input_shape = (rows,cols,3),activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(Conv2D(64, kernel_size = kernel,activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(128,kernel_size = kernel, activation = 'relu', padding='same'))#64
                model.add(BatchNormalization())
                model.add(Conv2D(128,kernel_size = kernel, activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same'))#128
                model.add(BatchNormalization())
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same'))
                model.add(BatchNormalization())
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same'))

            else:
                model.add(Conv2D(64, kernel_size = kernel,activation = 'relu', padding='same',input_shape = (rows, cols, 3), kernel_initializer = init))
                model.add(Conv2D(64, kernel_size = kernel,activation = 'relu', padding='same', kernel_initializer = init))
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(128,kernel_size = kernel, activation = 'relu', padding='same', kernel_initializer = init))
                model.add(Conv2D(128,kernel_size = kernel, activation = 'relu', padding='same', kernel_initializer = init))
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same', kernel_initializer = init))
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same', kernel_initializer = init))
                model.add(Conv2D(256,kernel_size = kernel, activation = 'relu', padding='same', kernel_initializer = init))
                model.add(MaxPooling2D(strides=2))
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same', kernel_initializer = init))
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same', kernel_initializer = init))
                model.add(Conv2D(512, kernel_size = kernel,activation = 'relu', padding='same', kernel_initializer = init))
            #Conv2D
            model.add(Dropout(0.3))
            model.add(Conv2D(512, (3, 3), activation='relu', dilation_rate = 2, kernel_initializer = init, padding = "same"))
            model.add(Dropout(0.3))
            model.add(Conv2D(256, (3, 3), activation='relu', dilation_rate = 2, kernel_initializer = init, padding = 'same'))
            model.add(Dropout(0.1))
            model.add(Conv2D(128, (3, 3), activation='relu', dilation_rate = 2, kernel_initializer = init, padding = 'same'))
            model.add(Dropout(0.1))
            model.add(Conv2D(64, (3, 3), activation='relu', dilation_rate = 2, kernel_initializer = init, padding = 'same'))
            model.add(Conv2D(1, (1, 1), activation='relu', dilation_rate = 1, kernel_initializer = init, padding = 'same'))

            sgd = SGD(learning_rate = 1e-7, decay = (5*1e-4), momentum = 0.95)
            #model.compile(optimizer=sgd, loss=euclidean_distance_loss, metrics=['mse'])
            #tf.keras.losses.Huber()
            model.compile(optimizer=Adam(1e-5), loss='accuracy', metrics=[mae, "mse"])
            #optimizer=Adam(1e-5)
            model = init_weights_vgg(model)

            return model

# %%
# !rm -r log
# Out:
# rm: cannot remove 'log': No such file or directory

# %%
from keras.callbacks import EarlyStopping
stopit = EarlyStopping(monitor="val_mae",patience=30)

# %%
batch = 1 #28

# %%
model = CrowdNet()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3bb01d760d85> in <cell line: 0>()
# ----> 1 model = CrowdNet()
#
# <ipython-input-15-7e72c1f6c8a8> in CrowdNet()
#      66             model.compile(optimizer=Adam(1e-5), loss='accuracy', metrics=[mae, "mse"])
#      67             #optimizer=Adam(1e-5)
# ---> 68             model = init_weights_vgg(model)
#      69
#      70             return model
#
# NameError: name 'init_weights_vgg' is not defined

# %%
train_gen = image_generator(img_paths_train,batch)

# %%
val_gen = image_generator(img_paths_test,batch)

# %%
sgd = SGD( decay = (5*1e-4), momentum = 0.95)
#model.compile(optimizer=sgd, loss=euclidean_distance_loss, metrics=['mse'])
#tf.keras.losses.CosineSimilarity(axis=1) =loss
model.compile(optimizer=Adam(1e-5), loss='mae', metrics=[mae, "mse", 'accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-3e1502b03e17> in <cell line: 0>()
#       2 #model.compile(optimizer=sgd, loss=euclidean_distance_loss, metrics=['mse'])
#       3 #tf.keras.losses.CosineSimilarity(axis=1) =loss
# ----> 4 model.compile(optimizer=Adam(1e-5), loss='mae', metrics=[mae, "mse", 'accuracy'])
#
# NameError: name 'model' is not defined
